# %% [markdown]
# # Import Library

# %%
import pickle
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Dataset
# Link : https://www.kaggle.com/datasets/azathoth42/myanimelist

# %%
UsersDF = pd.read_csv('../users_cleaned.csv')
AnimesDF = pd.read_csv('../anime_cleaned.csv')
ScoresDF = pd.read_csv('../animelists_cleaned.csv')

# %%
UsersDF.head()
# Out:
#          username  user_id  user_watching  user_completed  user_onhold  \
# 0        karthiga  2255153              3              49            1
# 1       Damonashu    37326             45             195           27
# 2           bskai   228342             25             414            2
# 3  terune_uzumaki   327311              5               5            0
# 4           Bas_G  5015094             35             114            6
#
#    user_dropped  user_plantowatch  user_days_spent_watching  gender  \
# 0             0                 0                 55.091667  Female
# 1            25                59                 82.574306    Male
# 2             5                11                159.483333    Male
# 3             0                 0                 11.394444  Female
# 4            20               175                 30.458333    Male
#
#               location           birth_date  access_rank            join_date  \
# ...

# %%
AnimesDF.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# ...

# %%
ScoresDF.head()
# Out:
#    username  anime_id  my_watched_episodes my_start_date my_finish_date  \
# 0  karthiga        21                  586    0000-00-00     0000-00-00
# 1  karthiga        59                   26    0000-00-00     0000-00-00
# 2  karthiga        74                   26    0000-00-00     0000-00-00
# 3  karthiga       120                   26    0000-00-00     0000-00-00
# 4  karthiga       178                   26    0000-00-00     0000-00-00
#
#    my_score  my_status  my_rewatching  my_rewatching_ep      my_last_updated  \
# 0         9          1            NaN                 0  2013-03-03 10:52:53
# 1         7          2            NaN                 0  2013-03-10 13:54:51
# 2         7          2            NaN                 0  2013-04-27 16:43:35
# 3         7          2            NaN                 0  2013-03-03 10:53:57
# 4         7          2            0.0                 0  2013-03-27 15:59:13
#
#   my_tags
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# Membuang Kolom pada ScoresDF yang tidak digunakan dan mengambil yang dibutuhkan pada rekomendasi

# %%
ScoresDF = ScoresDF[['username', 'anime_id', 'my_score', 'my_status']]
ScoresDF.head()
# Out:
#    username  anime_id  my_score  my_status
# 0  karthiga        21         9          1
# 1  karthiga        59         7          2
# 2  karthiga        74         7          2
# 3  karthiga       120         7          2
# 4  karthiga       178         7          2

# %% [markdown]
# Membuang Rating user yang nol

# %%
ScoresDF = ScoresDF[ScoresDF.my_score != 0]

# %% [markdown]
# Mengambil data anime yang bersifat series (TV)

# %%
AnimesDF = AnimesDF[AnimesDF.type == "TV"]
AnimesDF.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# ...

# %%
ScoresDF['my_score'].describe().apply(lambda x: format(x, '.2f')).reset_index()
# Out:
#    index     my_score
# 0  count  19172125.00
# 1   mean         7.59
# 2    std         1.71
# 3    min         1.00
# 4    25%         7.00
# 5    50%         8.00
# 6    75%         9.00
# 7    max        10.00

# %% [markdown]
# Menganalisa semua nilai kemungkinan pada score, akan digunakan sebagai parameter

# %%
lower_rating = ScoresDF['my_score'].min()
upper_rating = ScoresDF['my_score'].max()
print('Range of ratings vary between: {0} to {1}'.format(lower_rating, upper_rating))
# Out:
# Range of ratings vary between: 1 to 10

# %% [markdown]
# my_status pada ScoresDF berbentuk sebagai berikut
#
# - 1: watching
# - 2: completed
# - 3: on hold
# - 4: dropped
# - 6: plan to watch

# %%
# Menghitung Rating yang sudah diisi oleh user
RatedsPerUser = ScoresDF['username'].value_counts().reset_index().rename(columns={"username": "animes_rated", "index": "username"})
RatedsPerUser.head()
# Out:
#           username  animes_rated
# 0  _thiagobrisolla          3785
# 1    misterferrari          3442
# 2      Shouichirou          3439
# 3     SakataYusuke          3383
# 4           Kannei          3285

# %% [markdown]
# Karena data terlalu besar, maka akan diambil 1% data saja dari RatedsPerUser

# %%
RatedsPerUser = RatedsPerUser.sample(frac = 0.01, random_state = 24)
RatedsPerUser.head()
# Out:
#           username  animes_rated
# 57690  Otakuloid03           100
# 56423     ohmyL202           103
# 60260      beergod            92
# 23780     sora-tan           259
# 8015          Cinx           483

# %% [markdown]
# Membuat

# %%
ScoresDFNew = pd.merge(ScoresDF, RatedsPerUser, left_on = 'username', right_on = 'username', how = 'inner')
ScoresDFNew
# Out:
#             username  anime_id  my_score  my_status  animes_rated
# 0           Tsundora        21         2          4           259
# 1           Tsundora        59         5          2           259
# 2           Tsundora       210         5          2           259
# 3           Tsundora       249         7          4           259
# 4           Tsundora       269         6          2           259
# ...              ...       ...       ...        ...           ...
# 193267  Senpai_Helix      4214        10          2             4
# 193268  Senpai_Helix     18677         9          2             4
# 193269   Kiyoshi-Kun      1722        10          2             3
# 193270   Kiyoshi-Kun      2993        10          2             3
# 193271   Kiyoshi-Kun      7769        10          2             3
#
# [193272 rows x 5 columns]

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x="my_score", data=ScoresDF)
ax.set_yticklabels([num for num in ax.get_yticks()])
plt.tick_params(labelsize = 15)
plt.title("Count Ratings in data", fontsize = 20)
plt.xlabel("Ratings", fontsize = 20)
plt.ylabel("Number of Ratings", fontsize = 20)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_19004/816918237.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([num for num in ax.get_yticks()])

# %% [markdown]
# # Simpan ke Pickl

# %%
filename = 'users_data'
pickle.dump(UsersDF, open(filename,'wb'))

filename = 'animes_data'
pickle.dump(AnimesDF, open(filename,'wb'))

filename = 'scores_data'
pickle.dump(ScoresDF, open(filename,'wb'))
